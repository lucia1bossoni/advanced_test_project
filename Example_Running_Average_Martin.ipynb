# %%
import Running_Avg
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Create some noise signal, in this case a noisy sine.

import random
pi = np.pi

NoiseAmp = 0.3

x = np.arange(0, 2*pi, 0.01);
y = []

for point in x:
    y.append(np.sin(point) + (random.randint(0,1000)/500-1)*NoiseAmp)

# %%
plt.plot(x,y)
plt.plot(x,Running_Avg.Run_Avg(y,20),'r')
